# %% [markdown]
# ### [ 데이터 그룹화 및 시각화 ]
# - 데이터 : auto_mpg.csv
# - 실습 : 그룹화, 멀티인덱스, 시각화

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비 <hr>

# %%
## 모듈 로딩
import sys                  ## 다른 파일의 함수를 쓰는 방법    
sys.path.append(r'C:\Users\qjadl\Desktop\KDT10\EX_DATA_VS\COMM') ## 폴더까지만 넣기

import datautil as utill    ## 실제 개발할때는 못씀
import pandas as pd
import pandas as pd

# %%
## 데이터 준비
DATA_FILE = '../DATA/auto_mpg.csv'

## CSV => DataFrame 변환 저장
mpgDF = pd.read_csv(DATA_FILE)

# %%
## DataFrame 정보 확인   => 셀 나누는 이유는 위에서 확인하면 계속 주소랑 저장을 해야하기 때문에
display(mpgDF.head(3))
mpgDF.info()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
# ...

# %%
utill.print_info(mpgDF, 'mpgDF')
# Out:
# [mpgDF]==========
# obj.index   : RangeIndex(start=0, stop=398, step=1)
# obj.columns : Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')
# obj.shape   : (398, 9)
# obj.ndim    : 2D)
# obj.dtype   :
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
## DataFrame 정보 확인 
display(mpgDF.head(3))
mpgDF.info()
mpgDF.describe(include='all')
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
# ...

# %%
utill.summary(mpgDF, include_='all')
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
# ...

# %%
## Series 정보 확인
sr = pd.Series([10,20,30])
utill.summary(sr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      int64
# dtypes: int64(1)
# memory usage: 156.0 bytes
# count     3.0
# mean     20.0
# std      10.0
# min      10.0
# 25%      15.0
# 50%      20.0
# 75%      25.0
# max      30.0
# dtype: float64

# %% [markdown]
# [2] 데이터 전처리 <hr>

# %%
## [2-1] 결측치 체크 => isna()/isnull()
## 집계관련 메서드들 => axis 축 설정
## - 열/컬럼 단위 집계계산 axis=0 또는 'index'
## - 행/로우 단위 집계계산 axis=1 또는 'columns'
# mpgDF.isna()              ## => 결측치가 아니면 False로 결측치면 True로 표시됨 => 이거 자체가 DataFrame임
# mpgDF.isna().sum()        ## 컬럼별로 True(결측치)=1 / False(결측치아님)=0 을 더해서 반환해줌
# mpgDF.isna().sum(axis=1)  ##  행별로 True(결측치)=1 / False(결측치아님)=0 을 더해서 반환해줌  ## default는 0임

# %%
## [2-2] 컬럼별 고유값 검사 => unique() / nunique()  => n붙은건 개수를 알려줌
for col in mpgDF.columns:
    print(f'[{col}] ===> {mpgDF[col].nunique()}개')
    print(f'{mpgDF[col].unique()}')
# Out:
# [mpg] ===> 129개
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
# [cylinders] ===> 5개
# [8 4 6 3 5]
# [displacement] ===> 82개
# [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
## 컬럼별 고유값 검사 
utill.check_unique(mpgDF)  ## DataFrame을 가져와서 columns를 뽑아낸 뒤, unique/nunique를 뽑아내는 함수
# Out:
# [mpg] ===> 129개 / float64
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
# [cylinders] ===> 5개 / int64
# [8 4 6 3 5]
# [displacement] ===> 82개 / float64
# [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
# ...

# %%
## [2-3] 이상문자 처리 및 자료형 변환
## horsepower의 '?' 가 몇개 존재하는지 개수 체크
mpgDF['horsepower'].value_counts()['?']  ## count까지하면 각 행인덱스 종류가 몇개있는지 나오니깐 그때 ['?']를 가져오면 ?의 개수가 나옴

## 389개 중 6개 미미한 개수로 버리기로 결정
# mpgDF['horsepower'].replace('?', pd.NA, inplace=True)  ## inplace=True를 사용하면 '그냥 새로 저장해라' 라는 오류가 뜸
mpgDF['horsepower'] = mpgDF['horsepower'].replace('?', pd.NA)   ## '?'를 결측치로 바꾸고
mpgDF.dropna(inplace=True)                                      ## 결측치를 버림

# %%
## [2-4] 자료형 변환
mpgDF['horsepower'] = mpgDF['horsepower'].astype('float')       ## 결츨치 제거했으니 형변환하기

# %% [markdown]
# [3] 컬럼들의 관계 체크 <hr>
# - 주제 : 연비에 영향이 있는 요소/요인을 분석
# - 타겟 : 연비 컬럼 <= 다른 컬럼들의 영향으로 값이 결정. 종속변수컬럼
# - 피쳐 : 타겟 컬럼에 영향을 끼치는 컬럼들. 독립변수컬럼   [ Feature , 독립변수 ]
# - 컬럼들의 관계 정도 체크 => corr()

# %%
## mpg컬럼에 대한 다른 컬럼들과의 관계 수치값
mpgcorr = mpgDF.corr(numeric_only=True)['mpg']

# mpgcorr.sort_values().abs() >= 0.7  ## T/F로 반환   # ! -는 상관관계가 어떻게 되는지 -> 절댓값 1에 가까울수록 관계가 있는거임 -> -1이면 음의 상관관계 +1이면 양의 상관관계
mpgcorr = mpgcorr.sort_values().abs()
mpgcorr = mpgcorr[mpgcorr>=0.7]  ## 총 4개정도 연관이 있음을 알 수 있음
print(mpgcorr)
print(mpgcorr.index)
# Out:
# weight          0.832244
# displacement    0.805127
# horsepower      0.778427
# cylinders       0.777618
# mpg             1.000000
# Name: mpg, dtype: float64
# Index(['weight', 'displacement', 'horsepower', 'cylinders', 'mpg'], dtype='object')

# %%
## mpg 컬럼과 관련성이 높은 컬럼들의 시각화
## plot()
# mpgDF.plot(x='weight', y='mpg', kind='scatter') ## weight와 mpg의 상관관계를 그래프로 그림

for col in mpgcorr.index[:-1]: ## -1 까지 주는 이유는 마지막 columns은 mpg니깐 자기 자신이라서 제외한거임
    mpgDF.plot(x=col, y='mpg', kind='scatter', title=f'corr - {mpgcorr[col]}') ## title은

# %% [markdown]
# [4] 생산년도, 제조국에 따른 연비 비교 <hr>

# %%
## [4-1] 생산년도에 따른 데이터 그룹화
myearDGB = mpgDF.groupby(by='origin')  ## model year안에서 같은 값끼리 그룹을 만들어서 그게 행이 뭔지 반환하는거임   ## 원리 : unique값을 뽑아서 해당하는 값을 묶은거임

for k in myearDGB.groups:                       ## groups라는 속성 : 딕셔너리 형태로 그룹화 된 정보 반환 (key:[그룹에 해당하는 행 인덱스])
    ## get_group(그룹) : 해당 그룹 데이터프레임 반환
    print(k, myearDGB.get_group(k), sep='\n')   ##
# Out:
# 1
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...
